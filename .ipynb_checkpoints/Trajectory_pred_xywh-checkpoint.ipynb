# %%
import pandas as pd
import cv2
# %matplotlib inline
from matplotlib import pyplot as plt
import matplotlib
import tensorflow as tf
# import tensorflow.compat.v1 as tf
from tensorflow import keras
import numpy as np
from keras.preprocessing.sequence import pad_sequences
import os
import time
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from collections import OrderedDict
# from tensorflow.python.ops import math_ops
# import tensorflow.keras.backend as kb
from tensorflow_addons.utils.ensure_tf_install import _check_tf_version
_check_tf_version()
from tensorflow_addons import losses
import seaborn as sns

# Custom Functions
from load_data import Files_Load, Boxes, test_split_norm_abnorm, norm_train_max_min
from custom_metrics import bb_intersection_over_union, bb_intersection_over_union_np
from coordinate_change import xywh_tlbr, tlbr_xywh

# Kmeans
from sklearn.cluster import KMeans

# Need to figue out why this is not working
# from persistence1d import RunPersistence


from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
#plt.style.use(['dark_background'])
#plt.style.use(['dark_background'])
# plt.style.use('ggplot')

# %% [markdown]
# # GPU Check

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  2

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'),
#  PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
# gpus = tf.config.experimental.list_physical_devices('GPU')
# if gpus:
#   # Restrict TensorFlow to only allocate 1GB of memory on the first GPU
#   try:
#     tf.config.experimental.set_virtual_device_configuration(
#         gpus[1],
#         [tf.config.experimental.VirtualDeviceConfiguration(memory_limit=5500)])
#     logical_gpus = tf.config.experimental.list_logical_devices('GPU')
#     print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
#   except RuntimeError as e:
#     # Virtual devices must be set before GPUs have been initialized
#     print(e)

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %% [markdown]
# # Load Data

# %%
frames = 20
startvid=0
endvid=1

train_file = "/home/akanu/Dataset/Anomaly/Avenue_Dataset/bounding_box_tlbr/Txt_Data/Train_Box/"
test_file = "/home/akanu/Dataset/Anomaly/Avenue_Dataset/bounding_box_tlbr/Txt_Data/Test_Box/"

loc_files_train, loc_files_test, box_train_txt, box_test_txt = Files_Load(train_file, test_file)

# Don't forget to change to xywh 
traindict = Boxes(loc_files_train, box_train_txt, frames, pad ='pre', to_xywh=True)
testdict = Boxes(loc_files_test[startvid:endvid], box_test_txt[startvid:endvid], frames, pad ='pre', to_xywh = True)
abnormal_dict, normal_dict = test_split_norm_abnorm(testdict) #splits by which predicted frames are normal or not

# Normilize data
max1 = traindict['x_ppl_box'].max()
min1 = traindict['x_ppl_box'].min()
xx,yy = norm_train_max_min(data_dict = traindict, max1=max1,min1=min1)
xx_norm,yy_norm = norm_train_max_min(data_dict = normal_dict, max1=max1,min1=min1)
xx_abnorm,yy_abnorm = norm_train_max_min(data_dict = abnormal_dict, max1=max1,min1=min1)

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 32
xx_train, xx_val,yy_train,yy_val = train_test_split(xx,yy, test_size = 0.1)
train_univariate = tf.data.Dataset.from_tensor_slices((xx_train,yy_train))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_univariate = tf.data.Dataset.from_tensor_slices((xx_val,yy_val))
val_univariate = val_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# # Pedestrain

# %%
def pedsort(datadict):
    """
    This function saves each pedestrain bounding boxes in a video as a key
    To combine with multiple (x) videos would need to call this function x times
    and save result into another dict. Makes function moduluar 
    
    ped: Returned dict containing ped bounding boxes for unique tracking id's
    """
    
    ped = {}
    
    # For each pedestrain want to create a new key
    per_id = np.unique(datadict['frame_ppl_id'][:,-1,1])
    for i in per_id:
        ped[str(i)] = {}
        index = np.where(datadict['frame_ppl_id'][:,-1,1] == i)
        index = index[0][np.argsort(index[0])]
        # should ensure it sorted by frame
        temp = {}
        for key in datadict.keys():
            temp[key] = datadict[key][index]
            
        ped[str(i)] = temp
    return ped

# %% [markdown]
# # Video Results

# %%
def visual_ouput(model=None,max1 = None,min1=None, vid=None,pic_loc =None, output_dict=None,xywh = False):
    # Right now this only works for one video at a time
    
    xx,yy = norm_train_max_min(data_dict = output_dict, max1 = max1,min1 =min1)
    size = len(output_dict['frame_ppl_id'])
    
    #sort index by frames
    frame = []
    for i in range(0,size):
        #sort index by frames
        frame.append(output_dict['frame_ppl_id'][i,-1,0])
    
    frame = np.array(frame)
    sort_index = frame.argsort()
    #Sorted from first to last frame
    xx_scal, yy_scal = xx[sort_index], yy[sort_index]
    vid_file = output_dict['video_file'][sort_index] # not really needed if using one video
    frame_ppl = output_dict['frame_ppl_id'][sort_index]
    y_true = output_dict['y_ppl_box'][sort_index] # not normailized
    
    # Note that predicted outout is already sorted
    y_pred_scal = model.predict(xx_scal)
    y_pred = norm_train_max_min(data=y_pred_scal, max1 = max1,min1 =min1,undo_norm=True)
    

    stop = frame[sort_index][-1] + 1
    next_frame_index,j = 0,0
    
    #  Start Video
    loc_videos ="/home/akanu/Dataset/Anomaly/Avenue_Dataset/testing_videos/{:02}.avi".format(vid)
    video_capture = cv2.VideoCapture(loc_videos)

    if xywh:
        y_pred[:,0] = y_pred[:,0] - y_pred[:,2]/2
        y_pred[:,1] = y_pred[:,1] - y_pred[:,3]/2 # Now we are at tlwh
        y_pred[:,2:] = y_pred[:,:2] + y_pred[:,2:]
        
        y_true[:,0] = y_true[:,0] - y_true[:,2]/2
        y_true[:,1] = y_true[:,1] - y_true[:,3]/2 # Now we are at tlwh
        y_true[:,2:] = y_true[:,:2] + y_true[:,2:]
        
    for i in range(0,stop):
        ret, frame = video_capture.read()
        if i == frame_ppl[j,-1,0]: #finds the frame
            while i == frame_ppl[j,-1,0]:
                y_fr_act = y_true[j]
                y_fr_pred = y_pred[j]
                id1 = frame_ppl[j,-1,1]
#                 print("{}  ,{}".format(y_fr_act.shape, y_fr_pred.shape))

                gt_frame = frame.copy()
                pred_frame = frame.copy()
                both_frame = frame.copy()

    
                # Ground Truth
                cv2.rectangle(gt_frame, (int(y_fr_act[0]), int(y_fr_act[1])), (int(y_fr_act[2]), int(y_fr_act[3])),(0,255,0), 2)
#                 cv2.putText(gt_frame, str(frame_ppl[j,-1,1]),(int(y_fr_act[0]), int(y_fr_act[1])),0, 5e-3 * 200, (255,255,0),2)
                
                # Predicted
                cv2.rectangle(pred_frame, (int(y_fr_pred[0]), int(y_fr_pred[1])), (int(y_fr_pred[2]), int(y_fr_pred[3])),(0,255,255), 2)
#                 cv2.putText(pred_frame, str(frame_ppl[j,-1,1]),(int(y_fr_pred[2]), int(y_fr_pred[3])),0, 5e-3 * 200, (255,255,0),2)
                
                # Combined frame
                cv2.rectangle(both_frame, (int(y_fr_act[0]), int(y_fr_act[1])), (int(y_fr_act[2]), int(y_fr_act[3])),(0,255,0), 2)
#                 cv2.putText(both_frame, str(frame_ppl[j,-1,1]),(int(y_fr_act[0]), int(y_fr_act[1])),0, 5e-3 * 200, (255,255,0),2)
                cv2.rectangle(both_frame, (int(y_fr_pred[0]), int(y_fr_pred[1])), (int(y_fr_pred[2]), int(y_fr_pred[3])),(0,255,255), 2)
#                 cv2.putText(both_frame, str(frame_ppl[j,-1,1]),(int(y_fr_pred[2]), int(y_fr_pred[3])),0, 5e-3 * 200, (255,255,0),2)
                
                
                cv2.imwrite(pic_loc.format(vid,i,id1) + '_gt.jpg', gt_frame)
                cv2.imwrite(pic_loc.format(vid,i,id1) + '_pred.jpg', pred_frame)
                cv2.imwrite(pic_loc.format(vid,i,id1) + '_both.jpg', both_frame)



                
                next_frame_index +=1
                j = next_frame_index
#                 print('saved')
#                 print(j)
                if j == size:
                    return

# %% [markdown]
# # Train Model

# %%
with tf.device('/device:GPU:0'):
    lstm_20 = keras.Sequential()
    lstm_20.add(keras.layers.InputLayer(input_shape=xx.shape[-2:]))
    lstm_20.add(keras.layers.LSTM(4,return_sequences =True ))
    lstm_20.add(keras.layers.LSTM(3,return_sequences =True ))
    lstm_20.add(keras.layers.LSTM(6,return_sequences =True ))
    lstm_20.add(keras.layers.LSTM(4,return_sequences =True ))
    lstm_20.add(keras.layers.LSTM(4,return_sequences =True ))
    lstm_20.add(keras.layers.LSTM(4) )
    lstm_20.add(keras.layers.Dense(4) )
    opt = tf.keras.optimizers.Adam(learning_rate=8.726e-06)
    checkpoint_cb = keras.callbacks.ModelCheckpoint("lstm_5_xywh.h5", 
                                                       save_best_only = True)
    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.00005, patience=5)
#     lstm_20.compile(optimizer=opt, loss=losses.GIoULoss(), metrics=bb_intersection_over_union)
    # if use iou metric need to conver to tlbr 
    lstm_20.compile(optimizer=opt, loss='mse')

    lstm_20_history_1= lstm_20.fit(train_univariate,
                               validation_data = val_univariate,
                               epochs=100,
                               callbacks = [early_stopping, checkpoint_cb])

# %% [markdown]
# # Load Model (If model is trained)

# %%
model = tf.keras.models.load_model('lstm_5_xywh.h5', custom_objects = {'loss':'mse'} , compile=True)
lstm_20 = model
# Appears because of my custom loss fuction I could use evaluate

# %%
# lstm_20.evaluate(xx,yy)

# %% [markdown]
# # Check IOU for video files

# %%
# should make a for loop to evalute the table data

# %% [markdown]
# # Plot Data

# %%
pic_loc = "/home/akanu/git/anomalous_pred/resulting_images/xywh/test_abnorm/{}_{}_{}"
visual_ouput(model=lstm_20,max1 = max1, min1=min1, vid=1,pic_loc =pic_loc, output_dict=abnormal_dict,xywh = True)

# %%
pic_loc = "/home/akanu/git/anomalous_pred/resulting_images/xywh/test_norm/{}_{}_{}"
visual_ouput(model=lstm_20,max1 = max1, min1=min1, vid=1,pic_loc =pic_loc, output_dict=normal_dict,xywh = True)

# %% [markdown]
# # Sorting data

# %%
j ='1'
ped = pedsort(testdict)
x,y = norm_train_max_min(data_dict=ped[j], max1 = max1, min1=min1 )

# %%
out1 = lstm_20.predict(x)


out = bb_intersection_over_union_np(xywh_tlbr(out1), xywh_tlbr(y))
plt.plot(ped[j]['frame_ppl_id'][:,-1,0], np.squeeze(out),'-')
plt.plot(ped[j]['frame_ppl_id'][:,-1,0], ped[j]['abnormal'])
plt.xlabel('Frame')
plt.ylabel('IOU')
print(np.mean(out))
# sns.distplot(np.squeeze(out))
# Out:
# 0.8073108700281673

# %%
out1.shape
# Out:
# (368, 4)

# %% [markdown]
# # Using averaged iou to find Abnormal vs normal
# ## Doesn't work well

# %%
# Tries to find normal/abnormal pedestrian from averaged iou
iou_sum = []
for j in ped.keys():
#     print(j)
    x,y = norm_train_max_min(data_dict=ped[j], max1 = max1, min1=min1 )
    out1 = lstm_20.predict(x)
    out = bb_intersection_over_union_np(xywh_tlbr(out1),xywh_tlbr(y))
#     print(out.shape)
    iou_sum.append([np.mean(out), np.any(ped[j]['abnormal']) ])
iou_sum = np.array(iou_sum)

# %%
abnormal_ped = iou_sum[np.nonzero(iou_sum[:,1])]

# %%
norm_ped = iou_sum[np.where(iou_sum[:,1]==0)]

# %%
plt.plot(norm_ped[:,0],'-*', label='normal')
plt.plot(abnormal_ped[:,0], '-+', label='abnormal')
plt.xlabel('pedestrian')
plt.ylabel('Averaged IOU over time')
plt.legend()
# sns.distplot(norm_ped[:,0])
# sns.distplot(abnormal_ped[:,0])

# %% [markdown]
# # Finding distribution of normal vs abnormal pedestrains

# %%
iou_abnorm = []
iou_norm = []
for j in ped.keys():
#     print(j)
    x,y = norm_train_max_min(data_dict=ped[j], max1 = max1, min1=min1 )
    out1 = lstm_20.predict(x)
    out = bb_intersection_over_union_np(xywh_tlbr(out1),xywh_tlbr(y))
#     print(out.shape)
    if np.any(ped[j]['abnormal']):
#         iou_abnorm.append(np.squeeze(out).tolist()[:])
        iou_abnorm += np.squeeze(out).tolist()
    else:
#         iou_norm.append(np.squeeze(out).tolist())
        iou_norm += np.squeeze(out).tolist()

# iou_abnorm = np.array(iou_abnorm)
# iou_norm = np.array(iou_norm)

# %%
plt.style.use('classic')

# %%
sns.distplot(iou_abnorm, label='abnormal pedestrain')
sns.distplot(iou_norm, label='normal pedestrain')
plt.title('Test Video 1')
plt.legend()

# %%
len(testdict['abnormal'])

# %% [markdown]
# # Finding distrubtions of Normal vs abnormal frames

# %%
startvid =0
endvid=21

testdict = Boxes(loc_files_test[startvid:endvid], box_test_txt[startvid:endvid], frames, pad ='pre', to_xywh = True)

# %%
x,y = norm_train_max_min(data_dict=testdict, max1 = max1, min1=min1 )
out1 = lstm_20.predict(x)
out = bb_intersection_over_union_np(xywh_tlbr(out1),xywh_tlbr(y))
out = np.squeeze(out)
#     print(out.shape)
norm_index = np.where(testdict['abnormal']== 0)
abnorm_index = np.where(testdict['abnormal']== 1)

# %%
len(abnorm_index[0])

# %%
sns.distplot(out[abnorm_index], label='abnormal frames')
sns.distplot(out[norm_index], label='normal frames')
plt.title('All Test Video ')
plt.legend()

# %% [markdown]
# # Binary Classification on frames

# %%
x,y = norm_train_max_min(data_dict=testdict, max1 = max1, min1=min1 )
out1 = lstm_20.predict(x)
out = bb_intersection_over_union_np(xywh_tlbr(out1),xywh_tlbr(y))
out = np.squeeze(out)
np.random.seed(49)
rand = np.random.permutation(len(out))

# %%
def create_baseline():
    with tf.device('/device:GPU:0'):
        # create model
        model = keras.Sequential()
        model.add(keras.layers.Dense(1, input_dim=1, activation='relu'))
        model.add(keras.layers.Dense(1, activation='sigmoid'))
        # Compile model
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        return model

# %%
estimator = KerasClassifier(build_fn=create_baseline, epochs=100, batch_size=32, verbose=0)

# %%
kfold = StratifiedKFold(n_splits=10, shuffle=True)

# %%
results = cross_val_score(estimator, out[rand], testdict['abnormal'][rand], cv=kfold)

# %%
print("Baseline: %.2f%% (%.8f%%)" % (results.mean()*100, results.std()*100))

# %% [markdown]
# # Binary classifcation Even Split

# %%
startvid =0
endvid=21

testdict = Boxes(loc_files_test[startvid:endvid], box_test_txt[startvid:endvid], frames, pad ='pre', to_xywh = True)

# %%
x,y = norm_train_max_min(data_dict=testdict, max1 = max1, min1=min1 )
out1 = lstm_20.predict(x)
out = bb_intersection_over_union_np(xywh_tlbr(out1),xywh_tlbr(y))
out = np.squeeze(out)
np.random.seed(49)
rand = np.random.permutation(len(out))

# %%
abnorm_index = np.where(testdict['abnormal']==1)
norm_index = np.where(testdict['abnormal'] == 0)

# %%
print('abnormal: {}, normal: {}'.format(len(abnorm_index[0]), len(norm_index[0])))
# Want to create a function that allows me to vary the amount of abnormalites in the trainingg loader
# Want to also be able to vary amount of norms in training loader
# Need to keep track of indexes so that I can assign correct ones to abnormal truth
# Out:
# abnormal: 2930, normal: 112694

# %%
weight_scale = 1

# %%
# def vary_abnormal_normal_frames():
    abnorm_index = np.where(testdict['abnormal']==1)
    norm_index = np.where(testdict['abnormal'] == 0)
    abnormal_split = 0.5
    val_split = 0.3
    
    ratio = int(len(abnorm_index[0])*abnormal_split)
    a = abnorm_index[0][:ratio]
    b = norm_index[0][:ratio*weight_scale]
    
    val_ratio = int(val_split*len(a) )
    
    val_a = a[:val_ratio]
    val_b = b[:val_ratio*weight_scale]
    
    test_a = a[val_ratio:]
    test_b = b[val_ratio*weight_scale:]
    
    c = abnorm_index[0][ratio:]
    d = norm_index[0][ratio*weight_scale:]
    
    index = [a,b,c,d]
#     train  = {}
#     test = {}
#     for i in index[:2]:
#         x = out[i]
#         y = testdict['abnormal'][ i]
#         data.append
        
#     for i in index[2:]:
#         x = out[i]
#         y = testdict['abnormal'][ i]
#         data.append
        
    
    
    train_x_an = out[ test_a]
    train_y_an= testdict['abnormal'][ test_a ]
    
    train_x_n = out[ test_b]
    train_y_n = testdict['abnormal'][ test_b ]
    
    train_x = np.append(train_x_an,train_x_n,axis =0)
    train_y = np.append(train_y_an,train_y_n, axis = 0 )
    
    
    val_x_an = out[ val_a]
    val_y_an= testdict['abnormal'][ val_a ]
    
    val_x_n = out[ val_b]
    val_y_n = testdict['abnormal'][ val_b ]
    
    val_x = np.append(val_x_an,val_x_n,axis =0)
    val_y = np.append(val_y_an,val_y_n, axis = 0 )
       
    
    
    
    test_x_an = out[ c ]
    test_y_an= testdict['abnormal'][ c]
    
    test_x_n = out[ d ] 
    test_y_n = testdict['abnormal'][ d ]
    
    test_x = np.append(test_x_an, test_x_n, axis = 0)
    test_y = np.append(test_y_an, test_y_n, axis = 0)

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 32
train_univariate_1 = tf.data.Dataset.from_tensor_slices((train_x,train_y))
train_univariate_1 = train_univariate_1.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_univariate_1 = tf.data.Dataset.from_tensor_slices((val_x,val_y))
val_univariate_1 = val_univariate_1.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
def create_baseline():
    with tf.device('/device:GPU:0'):
        # create model
        neurons = 20
        dropout_ratio = 0.3
        model = keras.Sequential()
        model.add(keras.layers.Dense(neurons, input_dim=1, activation='relu'))
        model.add(keras.layers.Dense(neurons, input_dim=1, activation='relu'))
        model.add(keras.layers.Dropout(dropout_ratio))
        model.add(keras.layers.Dense(neurons, input_dim=1, activation='relu'))
        model.add(keras.layers.Dense(neurons, input_dim=1, activation='relu'))
        model.add(keras.layers.Dropout(dropout_ratio))
        model.add(keras.layers.Dense(1, activation='sigmoid'))
        # Compile model
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        return model

# %%
# np.random.seed(49)
# rand = np.random.permutation(len(out))
# size = 115624
# test ={}

# for i in testdict.keys():
#     testdict[i] = testdict[i][rand]

# %%
binary_model = create_baseline()

# %%
binary_model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 20)                40
# _________________________________________________________________
# dense_16 (Dense)             (None, 20)                420
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 20)                420
# _________________________________________________________________
# dense_18 (Dense)             (None, 20)                420
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 20)                0
# _________________________________________________________________
# dense_19 (Dense)             (None, 1)                 21
# =================================================================
# Total params: 1,321
# Trainable params: 1,321
# Non-trainable params: 0
# _________________________________________________________________

# %%
# x_train,x_test,y_train, y_test =train_test_split(out[rand], testdict['abnormal'][rand],shuffle=False,test_size=.5)
# Bad thing is can't guantree how many samples of abnormal is in x_train,x_test

# %%
# x_train,x_test,y_train, y_test =train_test_split(out, testdict['abnormal'],shuffle=False,test_size=.9)

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0.0005, 
                                                  patience=10, restore_best_weights=True)

# %%
bm = binary_model.fit(train_univariate_1, validation_data=val_univariate_1, epochs=300,callbacks=early_stopping)
# Out:
# Epoch 1/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6846 - accuracy: 0.5283 - val_loss: 0.6499 - val_accuracy: 0.9180
# Epoch 2/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.6368 - accuracy: 0.7022 - val_loss: 0.4887 - val_accuracy: 0.9294
# Epoch 3/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.5521 - accuracy: 0.7188 - val_loss: 0.3339 - val_accuracy: 0.9351
# Epoch 4/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.5277 - accuracy: 0.7149 - val_loss: 0.2964 - val_accuracy: 0.9260
# Epoch 5/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.5225 - accuracy: 0.7261 - val_loss: 0.2824 - val_accuracy: 0.9339
# Epoch 6/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.5159 - accuracy: 0.7300 - val_loss: 0.2839 - val_accuracy: 0.9305
# Epoch 7/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.5176 - accuracy: 0.7066 - val_loss: 0.2761 - val_accuracy: 0.9374
# Epoch 8/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.5159 - accuracy: 0.7290 - val_loss: 0.2744 - val_accuracy: 0.9282
# Epoch 9/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.5156 - accuracy: 0.7208 - val_loss: 0.2768 - val_accuracy: 0.9305
# Epoch 10/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.5147 - accuracy: 0.7208 - val_loss: 0.2710 - val_accuracy: 0.9294
# Epoch 11/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.5133 - accuracy: 0.7154 - val_loss: 0.2738 - val_accuracy: 0.9260
# Epoch 12/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.5045 - accuracy: 0.7169 - val_loss: 0.2637 - val_accuracy: 0.9260
# Epoch 13/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.5054 - accuracy: 0.7300 - val_loss: 0.2794 - val_accuracy: 0.9351
# Epoch 14/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4936 - accuracy: 0.7217 - val_loss: 0.2635 - val_accuracy: 0.9260
# Epoch 15/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4940 - accuracy: 0.7164 - val_loss: 0.2660 - val_accuracy: 0.9260
# Epoch 16/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4898 - accuracy: 0.7232 - val_loss: 0.2710 - val_accuracy: 0.9260
# Epoch 17/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4862 - accuracy: 0.7222 - val_loss: 0.2691 - val_accuracy: 0.9260
# Epoch 18/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4854 - accuracy: 0.7276 - val_loss: 0.2830 - val_accuracy: 0.9339
# Epoch 19/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4813 - accuracy: 0.7344 - val_loss: 0.2602 - val_accuracy: 0.9260
# Epoch 20/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4848 - accuracy: 0.7237 - val_loss: 0.2677 - val_accuracy: 0.9260
# Epoch 21/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4831 - accuracy: 0.7354 - val_loss: 0.2641 - val_accuracy: 0.9260
# Epoch 22/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4781 - accuracy: 0.7364 - val_loss: 0.2592 - val_accuracy: 0.9260
# Epoch 23/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4742 - accuracy: 0.7266 - val_loss: 0.2678 - val_accuracy: 0.9260
# Epoch 24/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4764 - accuracy: 0.7227 - val_loss: 0.2841 - val_accuracy: 0.9260
# Epoch 25/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4829 - accuracy: 0.7232 - val_loss: 0.2746 - val_accuracy: 0.9260
# Epoch 26/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4755 - accuracy: 0.7227 - val_loss: 0.2714 - val_accuracy: 0.9260
# Epoch 27/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4713 - accuracy: 0.7354 - val_loss: 0.2803 - val_accuracy: 0.9260
# Epoch 28/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4733 - accuracy: 0.7339 - val_loss: 0.2802 - val_accuracy: 0.9260
# Epoch 29/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4708 - accuracy: 0.7247 - val_loss: 0.2762 - val_accuracy: 0.9260
# Epoch 30/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4691 - accuracy: 0.7412 - val_loss: 0.2797 - val_accuracy: 0.9260
# Epoch 31/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4686 - accuracy: 0.7398 - val_loss: 0.2850 - val_accuracy: 0.9260
# Epoch 32/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4737 - accuracy: 0.7354 - val_loss: 0.2495 - val_accuracy: 0.9294
# Epoch 33/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4762 - accuracy: 0.7305 - val_loss: 0.2854 - val_accuracy: 0.9260
# Epoch 34/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4718 - accuracy: 0.7305 - val_loss: 0.3038 - val_accuracy: 0.9260
# Epoch 35/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4653 - accuracy: 0.7320 - val_loss: 0.2991 - val_accuracy: 0.9260
# Epoch 36/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4668 - accuracy: 0.7286 - val_loss: 0.2756 - val_accuracy: 0.9282
# Epoch 37/300
# 65/65 [==============================] - 0s 5ms/step - loss: 0.4686 - accuracy: 0.7339 - val_loss: 0.2796 - val_accuracy: 0.9282
# Epoch 38/300
# 65/65 [==============================] - ETA: 0s - loss: 0.4691 - accuracy: 0.72 - 0s 5ms/step - loss: 0.4686 - accuracy: 0.7286 - val_loss: 0.2840 - val_accuracy: 0.9260
# Epoch 39/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4734 - accuracy: 0.7227 - val_loss: 0.2741 - val_accuracy: 0.9294
# Epoch 40/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4736 - accuracy: 0.7325 - val_loss: 0.2617 - val_accuracy: 0.9294
# Epoch 41/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4694 - accuracy: 0.7276 - val_loss: 0.3037 - val_accuracy: 0.9260
# Epoch 42/300
# 65/65 [==============================] - 0s 6ms/step - loss: 0.4726 - accuracy: 0.7378 - val_loss: 0.2840 - val_accuracy: 0.9282

# %%
plt.plot(bm.history['val_loss'], label='val_loss')
plt.plot(bm.history['loss'], label='loss')
plt.legend()

# %%
bm.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(bm.history['val_accuracy'], label='val_acc')
plt.plot(bm.history['accuracy'], label='acc')
plt.legend()

# %%
y_pred = binary_model.predict(test_x)
plt.plot(y_pred, '*')

# %%
y_pred = binary_model.predict(test_x) > 0.5
tf.math.confusion_matrix(test_y,y_pred , num_classes = 2)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[70137, 41092],
#        [  195,  1270]], dtype=int32)>

# %% [markdown]
# Their does not seem to be a need to create a custom loss.
# Reason is that weihted_cross_entropy_with_logits exists

# %% [markdown]
# # Weighted loss

# %%
startvid =0
endvid=21

testdict = Boxes(loc_files_test[startvid:endvid], box_test_txt[startvid:endvid], frames, pad ='pre', to_xywh = True)

# %%
weight_scale = 10

# %%
x,y = norm_train_max_min(data_dict=testdict, max1 = max1, min1=min1 )
out1 = lstm_20.predict(x)
out = bb_intersection_over_union_np(xywh_tlbr(out1),xywh_tlbr(y))
out = np.squeeze(out)
np.random.seed(49)
rand = np.random.permutation(len(out))

# %%
# def vary_abnormal_normal_frames():
    abnorm_index = np.where(testdict['abnormal']==1)
    norm_index = np.where(testdict['abnormal'] == 0)
#     rand_an = np.random.permutation(len(abnorm_index[0]))
    abnormal_split = 0.9
    val_split = 0.2
    
    
    ratio = int(len(abnorm_index[0])*abnormal_split)
    a = abnorm_index[0][:ratio]
    b = norm_index[0][:ratio*weight_scale]
    
    initial_bias = np.log([ratio/(ratio*weight_scale)])

    
    val_ratio = int(val_split*len(a) )
    
    val_a = a[:val_ratio]
    val_b = b[:val_ratio*weight_scale]
    
    test_a = a[val_ratio:]
    test_b = b[val_ratio*weight_scale:]
    
    c = abnorm_index[0][ratio:]
    d = norm_index[0][ratio*weight_scale:]
    
    index = [a,b,c,d]
#     train  = {}
#     test = {}
#     for i in index[:2]:
#         x = out[i]
#         y = testdict['abnormal'][ i]
#         data.append
        
#     for i in index[2:]:
#         x = out[i]
#         y = testdict['abnormal'][ i]
#         data.append
        
    
    
    train_x_an = out[ test_a]
    train_y_an= testdict['abnormal'][ test_a ]
    
    train_x_n = out[ test_b]
    train_y_n = testdict['abnormal'][ test_b ]
    
    train_x = np.append(train_x_an,train_x_n,axis =0)
    train_y = np.append(train_y_an,train_y_n, axis = 0 )
    
    
    val_x_an = out[ val_a]
    val_y_an= testdict['abnormal'][ val_a ]
    
    val_x_n = out[ val_b]
    val_y_n = testdict['abnormal'][ val_b ]
    
    val_x = np.append(val_x_an,val_x_n,axis =0)
    val_y = np.append(val_y_an,val_y_n, axis = 0 )
       
    
    
    
    test_x_an = out[ c ]
    test_y_an= testdict['abnormal'][ c]
    
    test_x_n = out[ d ] 
    test_y_n = testdict['abnormal'][ d ]
    
    test_x = np.append(test_x_an, test_x_n, axis = 0)
    test_y = np.append(test_y_an, test_y_n, axis = 0)
    
#     return

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 32
train_univariate = tf.data.Dataset.from_tensor_slices((train_x,train_y))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_univariate = tf.data.Dataset.from_tensor_slices((val_x,val_y))
val_univariate = val_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %%
initial_bias = np.log([ratio/(ratio*weight_scale)])

# %%
initial_bias
# Out:
# array([-2.30258509])

# %%
print('training')
print('abnormal_mean: {}, normal_mean: {}'.format(train_x_an.mean(), train_x_n.mean()))
print('abnormal_mean: {}, normal_mean: {}'.format(train_y_an.mean(), train_y_n.mean()))
print("\n")

print('testing')
print('abnormal_mean: {}, normal_mean: {}'.format(test_x_an.mean(), test_x_n.mean()))
print('abnormal_mean: {}, normal_mean: {}'.format(test_y_an.mean(), test_y_n.mean()))
# Out:
# training
# abnormal_mean: 0.47592984910753605, normal_mean: 0.7224964023710309
# abnormal_mean: 1.0, normal_mean: 0.0
#
#
# testing
# abnormal_mean: 0.40022082005875337, normal_mean: 0.6783507693680348
# abnormal_mean: 1.0, normal_mean: 0.0

# %%
def weighted_binary(y,x):
    return tf.nn.weighted_cross_entropy_with_logits(y,x,pos_weight = weight_scale)

# %%
x = tf.constant([.8], dtype=tf.float32)

# %%
y = tf.constant([1], dtype=tf.float32)

# %%
 tf.nn.weighted_cross_entropy_with_logits(y,x,pos_weight = 1)
# Out:
# <tf.Tensor: shape=(1,), dtype=float32, numpy=array([0.37110066], dtype=float32)>

# %%
tf.keras.losses.binary_crossentropy(y, x, from_logits=True)
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=0.37110066>

# %%
def create_baseline_weighted(output_bias = None):
    with tf.device('/device:GPU:0'):
        # create model
        if output_bias is not None:
            output_bias = keras.initializers.Constant(output_bias)
        neurons = 30
        dropout_ratio = 0.3
        model = keras.Sequential()
        model.add(keras.layers.Dense(neurons, input_dim=1, activation='relu'))
        model.add(keras.layers.Dense(neurons, activation='relu'))
        model.add(keras.layers.Dropout(dropout_ratio))
        model.add(keras.layers.Dense(neurons, input_dim=1, activation='relu'))
        model.add(keras.layers.Dense(neurons, input_dim=1, activation='relu'))
        model.add(keras.layers.Dropout(dropout_ratio))
        model.add(keras.layers.Dense(1, bias_initializer=output_bias))
        # Compile model
#         wce = tf.nn.weighted_cross_entropy_with_logits(pos_weight = 10)
        model.compile(loss=weighted_binary, optimizer='adam', metrics=['accuracy'])
        return model

# %%
model_wl = create_baseline_weighted(output_bias = initial_bias )

# %%
model_wl.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 30)                60
# _________________________________________________________________
# dense_21 (Dense)             (None, 30)                930
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_22 (Dense)             (None, 30)                930
# _________________________________________________________________
# dense_23 (Dense)             (None, 30)                930
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 30)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 1)                 31
# =================================================================
# Total params: 2,881
# Trainable params: 2,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', min_delta=0.0005, 
                                                  patience=10, restore_best_weights=True)

# %%
model_wl.predict(test_x).min()
# Out:
# -2.3025851

# %%
wbm = model_wl.fit(train_univariate, validation_data=val_univariate, epochs=300,callbacks = early_stopping)
# Out:
# Epoch 1/300
# 726/726 [==============================] - 4s 5ms/step - loss: 1.2192 - accuracy: 0.7903 - val_loss: 0.7948 - val_accuracy: 0.8830
# Epoch 2/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8585 - accuracy: 0.8017 - val_loss: 0.8379 - val_accuracy: 0.7880
# Epoch 3/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8398 - accuracy: 0.7938 - val_loss: 0.8463 - val_accuracy: 0.8082
# Epoch 4/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8405 - accuracy: 0.7926 - val_loss: 0.8914 - val_accuracy: 0.8061
# Epoch 5/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8261 - accuracy: 0.7941 - val_loss: 0.9138 - val_accuracy: 0.7585
# Epoch 6/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8245 - accuracy: 0.7907 - val_loss: 0.9821 - val_accuracy: 0.8021
# Epoch 7/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8078 - accuracy: 0.8022 - val_loss: 0.9180 - val_accuracy: 0.7787
# Epoch 8/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8120 - accuracy: 0.7903 - val_loss: 0.9640 - val_accuracy: 0.6878
# Epoch 9/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8211 - accuracy: 0.7855 - val_loss: 1.0091 - val_accuracy: 0.8962
# Epoch 10/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8126 - accuracy: 0.7864 - val_loss: 1.0292 - val_accuracy: 0.8860
# Epoch 11/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8083 - accuracy: 0.7870 - val_loss: 1.0383 - val_accuracy: 0.8830
# Epoch 12/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8039 - accuracy: 0.7950 - val_loss: 1.1050 - val_accuracy: 0.8943
# Epoch 13/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8115 - accuracy: 0.7901 - val_loss: 1.0780 - val_accuracy: 0.8887
# Epoch 14/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7979 - accuracy: 0.7829 - val_loss: 1.1054 - val_accuracy: 0.8922
# Epoch 15/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7987 - accuracy: 0.7931 - val_loss: 1.0825 - val_accuracy: 0.8939
# Epoch 16/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8050 - accuracy: 0.7948 - val_loss: 1.0112 - val_accuracy: 0.8932
# Epoch 17/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8017 - accuracy: 0.7947 - val_loss: 1.0212 - val_accuracy: 0.8932
# Epoch 18/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8039 - accuracy: 0.7890 - val_loss: 1.0759 - val_accuracy: 0.7973
# Epoch 19/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7924 - accuracy: 0.7997 - val_loss: 1.1031 - val_accuracy: 0.8936
# Epoch 20/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7989 - accuracy: 0.7847 - val_loss: 1.0667 - val_accuracy: 0.8932
# Epoch 21/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.8016 - accuracy: 0.7893 - val_loss: 1.0246 - val_accuracy: 0.8477
# Epoch 22/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7919 - accuracy: 0.7940 - val_loss: 1.0070 - val_accuracy: 0.8882
# Epoch 23/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7964 - accuracy: 0.7915 - val_loss: 1.0561 - val_accuracy: 0.8924
# Epoch 24/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7986 - accuracy: 0.7829 - val_loss: 1.0216 - val_accuracy: 0.7594
# Epoch 25/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7877 - accuracy: 0.7935 - val_loss: 1.0364 - val_accuracy: 0.8956
# Epoch 26/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7993 - accuracy: 0.7830 - val_loss: 1.0013 - val_accuracy: 0.8958
# Epoch 27/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7995 - accuracy: 0.7894 - val_loss: 1.0714 - val_accuracy: 0.8825
# Epoch 28/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7971 - accuracy: 0.7919 - val_loss: 1.0121 - val_accuracy: 0.7388
# Epoch 29/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7805 - accuracy: 0.7935 - val_loss: 1.1420 - val_accuracy: 0.8924
# Epoch 30/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7955 - accuracy: 0.7911 - val_loss: 1.0385 - val_accuracy: 0.8629
# Epoch 31/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7899 - accuracy: 0.7932 - val_loss: 1.0046 - val_accuracy: 0.8534
# Epoch 32/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7945 - accuracy: 0.7961 - val_loss: 1.0065 - val_accuracy: 0.8732
# Epoch 33/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7852 - accuracy: 0.7943 - val_loss: 1.0142 - val_accuracy: 0.8399
# Epoch 34/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7878 - accuracy: 0.7971 - val_loss: 1.0621 - val_accuracy: 0.8544
# Epoch 35/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7836 - accuracy: 0.8004 - val_loss: 1.0384 - val_accuracy: 0.8587
# Epoch 36/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7878 - accuracy: 0.7973 - val_loss: 1.0154 - val_accuracy: 0.8085
# Epoch 37/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7819 - accuracy: 0.7965 - val_loss: 1.0214 - val_accuracy: 0.8479
# Epoch 38/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7875 - accuracy: 0.7916 - val_loss: 0.9816 - val_accuracy: 0.8344
# Epoch 39/300
# 726/726 [==============================] - 3s 5ms/step - loss: 0.7839 - accuracy: 0.7958 - val_loss: 1.0521 - val_accuracy: 0.8982

# %%
plt.plot(wbm.history['loss'], '-*',label='loss')
plt.plot(wbm.history['val_loss'], '-o',label='val_loss')
plt.legend()

# %%
plt.plot(wbm.history['accuracy'],'-*', label='acc')
plt.plot(wbm.history['val_accuracy'],'-*', label='val_acc')
plt.legend()

# %%
wbm.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
y_pred = model_wl.predict(test_x)
plt.plot(y_pred, '*')

# %%
y_pred = model_wl.predict(test_x) >0.5
tf.math.confusion_matrix(test_y, y_pred, num_classes =2)
# Out:
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[72489, 13835],
#        [   69,   224]], dtype=int32)>

# %% [markdown]
# # XY difference

# %%
x,y = norm_train_max_min(data_dict=testdict, max1 = max1, min1=min1 )
out = lstm_20.predict(x)
# np.random.seed(49)
# rand = np.random.permutation(len(out))

# %%
xy_diff = []
for i in range(1,len(out)):
    
    xy_diff.append(out[i,:] - out[i-1,:])

xy_diff = np.array(xy_diff)
out =np.sum(np.square(xy_diff[:,0:2]), axis=1)
# out =np.sum(xy_diff[:,0:4], axis=1)

# %% [markdown]
# ### 1)  XY difference from each other

# %%
norm_index = np.where(testdict['abnormal'][1:]== 0)
abnorm_index = np.where(testdict['abnormal'][1:]== 1)

# %%
sns.distplot(out[abnorm_index], label='abnormal frames')
sns.distplot(out[norm_index], label='normal frames')
plt.title('Test Video 1')
plt.legend()
plt.xlabel('XY Difference')
plt.ylabel('Frequency')

# %% [markdown]
# ### 2) XY difference  predicted frame from ground truth

# %%
x,y = norm_train_max_min(data_dict=testdict, max1 = max1, min1=min1 )
out = lstm_20.predict(x)

# %%
xy_diff = []
for i in range(0,len(out)):
    
    xy_diff.append(out[i,:] - y[i,:])

xy_diff = np.array(xy_diff)
out =np.sum(np.square(xy_diff[:,0:4]), axis=1)

# %%
norm_index = np.where(testdict['abnormal'][1:]== 0)
abnorm_index = np.where(testdict['abnormal'][1:]== 1)

# %%
sns.distplot(out[abnorm_index], label='abnormal frames')
sns.distplot(out[norm_index], label='normal frames')
plt.title('Difference from GT Test Video 2')
plt.legend()
plt.xlabel('XY Difference')
plt.ylabel('Frequency')

# %%
def create_baseline():
    with tf.device('/device:GPU:0'):
        # create model
        model = keras.Sequential()
        model.add(keras.layers.Dense(1, input_dim=1, activation='relu'))
        model.add(keras.layers.Dense(1, activation='sigmoid'))
        # Compile model
        model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
        return model

# %%
estimator = KerasClassifier(build_fn=create_baseline, epochs=100, batch_size=32, verbose=0)
kfold = StratifiedKFold(n_splits=10, shuffle=True)

# %%
results = cross_val_score(estimator, out[rand], testdict['abnormal'][rand], cv=kfold)

# %%
plt.plot(ped[j]['frame_ppl_id'][1:,-1,0], out,'*')
# plt.plot(ped['1']['frame_ppl_id'][1:,-1,0], xy_diff[:,0],'-+')
# plt.plot(ped['1']['frame_ppl_id'][1:,-1,0], xy_diff[:,1],'-0')

# %%
ped[j]['abnormal']

# %% [markdown]
# # Abnormal Through IOU

# %%
j ='1'
out1 = lstm_20.predict(ped[j]['x_ppl_box'])
out = norm_train_max_min(data=out1, max1 = max1,min1 =min1,undo_norm=True)
bb_intersection_over_union(xywh_tlbr(out), xywh_tlbr(ped[j]['y_ppl_box']))

# %% [markdown]
# # K means Clustering Approach

# %% [markdown]
# https://towardsdatascience.com/understanding-k-means-clustering-in-machine-learning-6a6e67336aa1

# %%
x,y = norm_train_max_min(data_dict=testdict, max1 = max1, min1=min1 )
out = lstm_20.predict(x)
# out = bb_intersection_over_union_np(xywh_tlbr(out1),xywh_tlbr(y))
# out = np.squeeze(out)
# np.random.seed(49)
# rand = np.random.permutation(len(out))

# %%
# y_pred_scal = model.predict(xx_test)
# y_pred = norm_train_max_min(data=y_pred_scal, max1 = max1,min1 =min1,undo_norm=True)

# %%
kmean_scal = KMeans(n_clusters=2)
kmean = KMeans(n_clusters=2)

# %%
kmean_scal.fit(y_pred_scal[:,0:2])
kmean.fit(y_pred[:,0:2])
# Out:
# ---------------------------------------------------
# NameError         Traceback (most recent call last)
# <ipython-input-43-78dd08088d2a> in <module>
# ----> 1 kmean_scal.fit(y_pred_scal[:,0:2])
#       2 kmean.fit(y_pred[:,0:2])
#
# NameError: name 'y_pred_scal' is not defined

# %%
out = kmean_scal.cluster_centers_
out

# %%
out1 = kmean.cluster_centers_
out1

# %%
traindict.keys()

# %%
traindict['frame_ppl_id'][0:3].shape

# %%
ped = pedsort(testdict)

# %%
j='86'
x,y = norm_train_max_min(data_dict=ped[j], max1=max1, min1=min1 )

out1 = model.predict(x)
bb_intersection_over_union(out1,y)

# %%
plt.scatter(y_pred_scal[:,0], y_pred_scal[:,1],s=1, c='b')
plt.scatter(out[0,0], out[0,1],s=200, c ='g', marker='s')
plt.scatter(out[1,0], out[1,1], s=200, c ='r', marker='s')

# %%
plt.scatter(y_pred[:,0], y_pred[:,1],s=1, c='b')
plt.scatter(out1[0,0], out1[0,1],s=200, c ='g', marker='s')
plt.scatter(out1[1,0], out1[1,1], s=200, c ='r', marker='s')

# %% [markdown]
# Suggestion that x,y is not enough to create a hyoer parameter to seperate abnomaly and normal pedestrains. Makes sense because abnormal and normal pedestrains walk over the same spatial features. Trying to do it for all pedestrains
