# %% [markdown]
# Experiment 2: Set aside a testing set that contains equal amounts of normal and abnormal subset. Use the rest of data for training and use custom loss to scale based on training ratio of normal to abnormal subsets. Also add in all the normal data from training of the lstm network into training of binary classification.

# %%
import pandas as pd
import seaborn as sns
import cv2
import numpy as np

from matplotlib import pyplot as plt
import matplotlib
# %matplotlib inline

import tensorflow as tf
# import tensorflow.compat.v1 as tf
from tensorflow import keras
from keras.preprocessing.sequence import pad_sequences
import os, sys, time
from math import floor
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# from collections import OrderedDict
# from tensorflow.python.ops import math_ops
# import tensorflow.keras.backend as kb
from tensorflow_addons.utils.ensure_tf_install import _check_tf_version
_check_tf_version()
from tensorflow_addons import losses

# Custom Functions
# Added to path by using sys.path.append('')
sys.path.append('/home/akanu/git/anomalous_pred/custom_functions')
from load_data import Files_Load, Boxes, test_split_norm_abnorm, norm_train_max_min
from custom_metrics import bb_intersection_over_union, bb_intersection_over_union_np
from coordinate_change import xywh_tlbr, tlbr_xywh
from pedsort import pedsort
from load_data_binary_class import return_indices, binary_data_split, same_ratio_split_train_val

# Kmeans
from sklearn.cluster import KMeans

# Need to figue out why this is not working
# from persistence1d import RunPersistence


from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
# Out:
# Using TensorFlow backend.

# %%
plt.style.use('classic')

# %%
print("Num GPUs Available: ", len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  2

# %%
gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
        print(e)
# Out:
# 2 Physical GPUs, 2 Logical GPUs

# %% [markdown]
# # Load Data

# %%
frames = 20

train_file = "/home/akanu/Dataset/Anomaly/Avenue_Dataset/bounding_box_tlbr/Txt_Data/Train_Box/"
test_file = "/home/akanu/Dataset/Anomaly/Avenue_Dataset/bounding_box_tlbr/Txt_Data/Test_Box/"

loc_files_train, loc_files_test, box_train_txt, box_test_txt = Files_Load(train_file, test_file)

# Don't forget to change to xywh 
traindict = Boxes(loc_files_train, box_train_txt, frames, pad ='pre', to_xywh=True)
testdict = Boxes(loc_files_test, box_test_txt, frames, pad ='pre', to_xywh = True)
abnormal_dict, normal_dict = test_split_norm_abnorm(testdict) #splits by which predicted frames are normal or not

# Normilize data
max1 = traindict['x_ppl_box'].max()
min1 = traindict['x_ppl_box'].min()
xx,yy = norm_train_max_min(data_dict = traindict, max1=max1,min1=min1)
xx_norm,yy_norm = norm_train_max_min(data_dict = normal_dict, max1=max1,min1=min1)
xx_abnorm,yy_abnorm = norm_train_max_min(data_dict = abnormal_dict, max1=max1,min1=min1)

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 32
xx_train, xx_val,yy_train,yy_val = train_test_split(xx,yy, test_size = 0.3)
train_univariate = tf.data.Dataset.from_tensor_slices((xx_train,yy_train))
train_univariate = train_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_univariate = tf.data.Dataset.from_tensor_slices((xx_val,yy_val))
val_univariate = val_univariate.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# # Load or Train LSTM model

# %%
sys.path.insert(0,'/home/akanu/git/anomalous_pred/model')
from lstm_models import lstm_xywh_avenue_20

# %%
model_loc = '/home/akanu/git/anomalous_pred/saved_models'
nc=['lstm', 'xywh', 'avenue', frames]

# %%
loaded_model = os.path.join(model_loc,
                            '{}_{}_{}_{}.h5'.format(nc[0], nc[1],nc[2], nc[3]))
lstm_20 = tf.keras.models.load_model(loaded_model,  
                                   custom_objects = {'loss':'mse'} , 
                                   compile=True)

# %% [markdown]
# # Load Data For Binary Network

# %%
indices = return_indices(testdict['abnormal'], abnormal_split=0.5)

# %%
x,y = norm_train_max_min(data_dict=testdict, max1 = max1, min1=min1 )
train_x_per_combine,train_y_per_combine, test_x, test_y = binary_data_split(x,y, lstm_20, indices)

# %%
out = lstm_20.predict(xx)

# %%
out = bb_intersection_over_union_np(xywh_tlbr(out),xywh_tlbr(yy))
out = np.squeeze(out)

# %%
training_set_from_lstm = np.append(np.reshape(out,(1, len(out)) ), 
                                   np.zeros((1,len(out))), axis=0)
train_x_with_lstm_train_set = np.append(train_x_per_combine,training_set_from_lstm, axis=1)
train_y_with_lstm_train_set = np.append(train_y_per_combine, np.zeros(len(out)))

# %%
val_x, val_y, train_x, train_y = same_ratio_split_train_val(train_x_with_lstm_train_set,
                                                            train_y_with_lstm_train_set,
                                                            val_ratio = 0.3)

# %%
BUFFER_SIZE = 10000
BATCH_SIZE = 32
# Note that I need to index into correct column as one is IOU
# and last column is index values to map back into datadicg
train_bm = tf.data.Dataset.from_tensor_slices((train_x[0,:],train_y))
train_bm = train_bm.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
val_bm = tf.data.Dataset.from_tensor_slices((val_x[0,:],val_y))
val_bm = val_bm.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE)

# %% [markdown]
# # Load/Train Binary Model

# %%
train =True
pos = np.where(train_y == 1)[0]
neg = np.where(train_y ==0)[0]

# %%
weight_ratio = len(pos)/len(neg)

# %%
initial_bias= np.log(weight_ratio)

# %%
sys.path.insert(0,'/home/akanu/git/anomalous_pred/model')
from binary_classification import Dense_5_Drop_2

# %%
nc_bin = ['Dense_5_Drop_5', 'xywh','avenue', frames, 0.500]

# %%
def weighted_binary(y,x):
    return tf.nn.weighted_cross_entropy_with_logits(y,x,pos_weight = 1/weight_ratio)

# %%
# binary_model = create_baseline_weighted(initial_bias)
if train:
    bm_history,bm_model = Dense_5_Drop_2(train_bm,
                                  val_bm,
                                  os.path.join(model_loc, 'Experiment_2'),
                                  nc_bin,
                                  weighted_binary,
                                  initial_bias,
                                  300
                                 )
# Out:
# Epoch 1/300
# 5497/5497 [==============================] - 30s 5ms/step - loss: 5.1030 - accuracy: 0.9942 - val_loss: 5.0618 - val_accuracy: 0.9942
# Epoch 2/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 5.0204 - accuracy: 0.9942 - val_loss: 4.9494 - val_accuracy: 0.9942
# Epoch 3/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 4.8874 - accuracy: 0.9942 - val_loss: 4.7881 - val_accuracy: 0.9942
# Epoch 4/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 4.6914 - accuracy: 0.9942 - val_loss: 4.5592 - val_accuracy: 0.9942
# Epoch 5/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 4.4129 - accuracy: 0.9942 - val_loss: 4.2352 - val_accuracy: 0.9942
# Epoch 6/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 4.0586 - accuracy: 0.9942 - val_loss: 3.8616 - val_accuracy: 0.9942
# Epoch 7/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 3.6488 - accuracy: 0.9942 - val_loss: 3.4737 - val_accuracy: 0.9942
# Epoch 8/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 3.2216 - accuracy: 0.9930 - val_loss: 3.1608 - val_accuracy: 0.9942
# Epoch 9/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.9260 - accuracy: 0.9777 - val_loss: 2.9787 - val_accuracy: 0.9942
# Epoch 10/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.7589 - accuracy: 0.9653 - val_loss: 2.8821 - val_accuracy: 0.9942
# Epoch 11/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.6720 - accuracy: 0.9516 - val_loss: 2.8250 - val_accuracy: 0.9942
# Epoch 12/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.5802 - accuracy: 0.9449 - val_loss: 2.8060 - val_accuracy: 0.9942
# Epoch 13/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.5722 - accuracy: 0.9464 - val_loss: 2.7615 - val_accuracy: 0.9942
# Epoch 14/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.5046 - accuracy: 0.9429 - val_loss: 2.7308 - val_accuracy: 0.9942
# Epoch 15/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.4817 - accuracy: 0.9461 - val_loss: 2.6994 - val_accuracy: 0.9942
# Epoch 16/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.4433 - accuracy: 0.9450 - val_loss: 2.7252 - val_accuracy: 0.9942
# Epoch 17/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.4292 - accuracy: 0.9476 - val_loss: 2.6670 - val_accuracy: 0.9942
# Epoch 18/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.3759 - accuracy: 0.9429 - val_loss: 2.6286 - val_accuracy: 0.9942
# Epoch 19/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.3401 - accuracy: 0.9423 - val_loss: 2.5986 - val_accuracy: 0.9942
# Epoch 20/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.3064 - accuracy: 0.9455 - val_loss: 2.5627 - val_accuracy: 0.9942
# Epoch 21/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.2187 - accuracy: 0.9416 - val_loss: 2.5384 - val_accuracy: 0.9942
# Epoch 22/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.1834 - accuracy: 0.9477 - val_loss: 2.5077 - val_accuracy: 0.9942
# Epoch 23/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.1731 - accuracy: 0.9447 - val_loss: 2.4609 - val_accuracy: 0.9942
# Epoch 24/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.0920 - accuracy: 0.9467 - val_loss: 2.4331 - val_accuracy: 0.9942
# Epoch 25/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.0764 - accuracy: 0.9515 - val_loss: 2.4002 - val_accuracy: 0.9942
# Epoch 26/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.0411 - accuracy: 0.9513 - val_loss: 2.3603 - val_accuracy: 0.9942
# Epoch 27/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 2.0155 - accuracy: 0.9546 - val_loss: 2.3161 - val_accuracy: 0.9942
# Epoch 28/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.9364 - accuracy: 0.9514 - val_loss: 2.2848 - val_accuracy: 0.9942
# Epoch 29/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.8913 - accuracy: 0.9527 - val_loss: 2.2511 - val_accuracy: 0.9942
# Epoch 30/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.8551 - accuracy: 0.9506 - val_loss: 2.2443 - val_accuracy: 0.9942
# Epoch 31/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.8230 - accuracy: 0.9487 - val_loss: 2.2020 - val_accuracy: 0.9942
# Epoch 32/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.7730 - accuracy: 0.9544 - val_loss: 2.1658 - val_accuracy: 0.9942
# Epoch 33/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.7684 - accuracy: 0.9528 - val_loss: 2.1388 - val_accuracy: 0.9942
# Epoch 34/300
# 5497/5497 [==============================] - 28s 5ms/step - loss: 1.7279 - accuracy: 0.9542 - val_loss: 2.0927 - val_accuracy: 0.9942
# Epoch 35/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.6668 - accuracy: 0.9507 - val_loss: 2.0690 - val_accuracy: 0.9942
# Epoch 36/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.6400 - accuracy: 0.9464 - val_loss: 2.0311 - val_accuracy: 0.9942
# Epoch 37/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.6229 - accuracy: 0.9470 - val_loss: 2.0071 - val_accuracy: 0.9942
# Epoch 38/300
# 5497/5497 [==============================] - 28s 5ms/step - loss: 1.5032 - accuracy: 0.9438 - val_loss: 1.9889 - val_accuracy: 0.9942
# Epoch 39/300
# 5497/5497 [==============================] - 28s 5ms/step - loss: 1.4794 - accuracy: 0.9437 - val_loss: 1.9771 - val_accuracy: 0.9942
# Epoch 40/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.5065 - accuracy: 0.9361 - val_loss: 1.9510 - val_accuracy: 0.9942
# Epoch 41/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.4467 - accuracy: 0.9358 - val_loss: 1.9412 - val_accuracy: 0.9942
# Epoch 42/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.4215 - accuracy: 0.9371 - val_loss: 1.9200 - val_accuracy: 0.9942
# Epoch 43/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.3977 - accuracy: 0.9351 - val_loss: 1.9004 - val_accuracy: 0.9942
# Epoch 44/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.4129 - accuracy: 0.9358 - val_loss: 1.8953 - val_accuracy: 0.9886
# Epoch 45/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.4022 - accuracy: 0.9323 - val_loss: 1.8765 - val_accuracy: 0.9869
# Epoch 46/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.3474 - accuracy: 0.9304 - val_loss: 1.8937 - val_accuracy: 0.9862
# Epoch 47/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.3185 - accuracy: 0.9269 - val_loss: 1.9040 - val_accuracy: 0.9856
# Epoch 48/300
# 5497/5497 [==============================] - 28s 5ms/step - loss: 1.3490 - accuracy: 0.9262 - val_loss: 1.8639 - val_accuracy: 0.9842
# Epoch 49/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.3336 - accuracy: 0.9255 - val_loss: 1.8595 - val_accuracy: 0.9834
# Epoch 50/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.3231 - accuracy: 0.9271 - val_loss: 1.8635 - val_accuracy: 0.9828
# Epoch 51/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.3191 - accuracy: 0.9267 - val_loss: 1.8435 - val_accuracy: 0.9819
# Epoch 52/300
# 5497/5497 [==============================] - 28s 5ms/step - loss: 1.2890 - accuracy: 0.9250 - val_loss: 1.8530 - val_accuracy: 0.9815
# Epoch 53/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.3312 - accuracy: 0.9245 - val_loss: 1.8513 - val_accuracy: 0.9809
# Epoch 54/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2790 - accuracy: 0.9210 - val_loss: 1.8733 - val_accuracy: 0.9810
# Epoch 55/300
# 5497/5497 [==============================] - 28s 5ms/step - loss: 1.2958 - accuracy: 0.9248 - val_loss: 1.8576 - val_accuracy: 0.9802
# Epoch 56/300
# 5497/5497 [==============================] - 28s 5ms/step - loss: 1.2659 - accuracy: 0.9190 - val_loss: 1.8542 - val_accuracy: 0.9797
# Epoch 57/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2937 - accuracy: 0.9225 - val_loss: 1.8448 - val_accuracy: 0.9793
# Epoch 58/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2677 - accuracy: 0.9173 - val_loss: 1.8432 - val_accuracy: 0.9788
# Epoch 59/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2651 - accuracy: 0.9209 - val_loss: 1.8471 - val_accuracy: 0.9787
# Epoch 60/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2780 - accuracy: 0.9231 - val_loss: 1.8318 - val_accuracy: 0.9784
# Epoch 61/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2502 - accuracy: 0.9177 - val_loss: 1.8417 - val_accuracy: 0.9782
# Epoch 62/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2507 - accuracy: 0.9150 - val_loss: 1.8508 - val_accuracy: 0.9780
# Epoch 63/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2667 - accuracy: 0.9186 - val_loss: 1.8226 - val_accuracy: 0.9776
# Epoch 64/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2433 - accuracy: 0.9159 - val_loss: 1.8651 - val_accuracy: 0.9779
# Epoch 65/300
# 5497/5497 [==============================] - 28s 5ms/step - loss: 1.2306 - accuracy: 0.9163 - val_loss: 1.8622 - val_accuracy: 0.9778
# Epoch 66/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2540 - accuracy: 0.9172 - val_loss: 1.8493 - val_accuracy: 0.9774
# Epoch 67/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2652 - accuracy: 0.9168 - val_loss: 1.8469 - val_accuracy: 0.9772
# Epoch 68/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2164 - accuracy: 0.9165 - val_loss: 1.8505 - val_accuracy: 0.9770
# Epoch 69/300
# 5497/5497 [==============================] - 28s 5ms/step - loss: 1.2541 - accuracy: 0.9171 - val_loss: 1.8549 - val_accuracy: 0.9771
# Epoch 70/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2606 - accuracy: 0.9164 - val_loss: 1.8421 - val_accuracy: 0.9769
# Epoch 71/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2620 - accuracy: 0.9205 - val_loss: 1.8383 - val_accuracy: 0.9768
# Epoch 72/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2252 - accuracy: 0.9148 - val_loss: 1.8563 - val_accuracy: 0.9770
# Epoch 73/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2699 - accuracy: 0.9197 - val_loss: 1.8351 - val_accuracy: 0.9767
# Epoch 74/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2577 - accuracy: 0.9159 - val_loss: 1.8471 - val_accuracy: 0.9768
# Epoch 75/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2481 - accuracy: 0.9155 - val_loss: 1.8332 - val_accuracy: 0.9765
# Epoch 76/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2408 - accuracy: 0.9156 - val_loss: 1.8598 - val_accuracy: 0.9769
# Epoch 77/300
# 5497/5497 [==============================] - 28s 5ms/step - loss: 1.2550 - accuracy: 0.9169 - val_loss: 1.8554 - val_accuracy: 0.9766
# Epoch 78/300
# 5497/5497 [==============================] - 29s 5ms/step - loss: 1.2763 - accuracy: 0.9181 - val_loss: 1.8313 - val_accuracy: 0.9763

# %%
plot_loc = '/home/akanu/git/anomalous_pred/plots/experiment_2/Avenue/'

# %%
fig, ax = plt.subplots(nrows=1,ncols=1)
ax.plot(bm_history.history['loss'] , '--',color='black', label='Loss')
ax.plot(bm_history.history['val_loss'], '-o',color='red', label = 'Validation Loss')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Non-Zero Initial Bias Last Layer')
# plot_loc = '/home/akanu/git/anomalous_pred/plots/experiment_2/Avenue/loss_{}_{}_{}_{}_{}.jpg'
fig.savefig(os.path.join(plot_loc, 'loss_{}_{}_{}_{}_{}.jpg'.format(nc_bin[0],
                                                                    nc_bin[1],
                                                                    nc_bin[2],
                                                                    nc_bin[3],
                                                                    nc_bin[4])))

# %%
fig, ax = plt.subplots(nrows=1,ncols=1)
ax.plot(bm_history.history['accuracy'] , '--',color='black', label='Acc')
ax.plot(bm_history.history['val_accuracy'], '-o',color ='red',label = 'Validation Acc')
plt.legend()
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Non-Zero Initial Bias Last Layer')
fig.savefig(os.path.join(plot_loc, 'acc_{}_{}_{}_{}_{}.jpg'.format(nc_bin[0],
                                                                    nc_bin[1],
                                                                    nc_bin[2],
                                                                    nc_bin[3],
                                                                    nc_bin[4])))

# %%
fig,ax = plt.subplots(1,1)
ax.plot(bm_model.predict(test_x[0,:]), '*')
plt.title('Non-Zero Initial Bias Last Layer')
plt.ylabel('Predicted Y')
fig.savefig(os.path.join(plot_loc, 'scatter_{}_{}_{}_{}_{}.jpg'.format(nc_bin[0],
                                                                    nc_bin[1],
                                                                    nc_bin[2],
                                                                    nc_bin[3],
                                                                    nc_bin[4])))
