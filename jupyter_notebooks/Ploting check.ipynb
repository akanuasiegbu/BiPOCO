# %%
import cv2
from os import listdir
from os.path import isfile, join, isdir
import numpy as np
from PIL import Image
# import config as Config
import matplotlib.pyplot as plt

# %%
path = '/home/akanu/akanu/projects/anomalous_pred/results_all_datasets/experiment_traj_model/visual_trajectory/01_0026_304_6_gt'

loc = path +'/01_0026___285__6_input.jpg'

# %%
image = cv2.imread(loc)

# %%
plt.imshow(image)

# %%
cv2.rectangle(image, (int(300), int(152)), (int(312), int(188)),(100,255,0), 2)
# Out:
# array([[[101, 102, 100],
#         [101, 102, 100],
#         [101, 102, 100],
#         ...,
#         [ 18,  33,  19],
#         [ 20,  33,  19],
#         [ 23,  36,  22]],
#
#        [[102, 103, 101],
#         [102, 103, 101],
#         [101, 102, 100],
#         ...,
#         [ 21,  36,  22],
#         [ 23,  36,  22],
#         [ 25,  38,  24]],
#
#        [[103, 104, 102],
#         [102, 103, 101],
#         [102, 103, 101],
#         ...,
#         [ 30,  42,  30],
#         [ 30,  42,  30],
#         [ 31,  43,  31]],
#
#        ...,
#
#        [[137, 132, 129],
#         [137, 132, 129],
#         [137, 132, 129],
#         ...,
#         [150, 143, 140],
#         [151, 144, 141],
#         [154, 147, 144]],
#
#        [[136, 131, 128],
#         [136, 131, 128],
#         [136, 131, 128],
#         ...,
#         [152, 145, 142],
#         [152, 145, 142],
#         [154, 147, 144]],
#
#        [[135, 130, 127],
#         [135, 130, 127],
#         [135, 130, 127],
# ...

# %%
plt.imshow(image)

# %%
cv2.rectangle(image, (int(290), int(159)), (int(322), int(265)),(100,255,0), 2)
# Out:
# array([[[101, 102, 100],
#         [101, 102, 100],
#         [101, 102, 100],
#         ...,
#         [ 18,  33,  19],
#         [ 20,  33,  19],
#         [ 23,  36,  22]],
#
#        [[102, 103, 101],
#         [102, 103, 101],
#         [101, 102, 100],
#         ...,
#         [ 21,  36,  22],
#         [ 23,  36,  22],
#         [ 25,  38,  24]],
#
#        [[103, 104, 102],
#         [102, 103, 101],
#         [102, 103, 101],
#         ...,
#         [ 30,  42,  30],
#         [ 30,  42,  30],
#         [ 31,  43,  31]],
#
#        ...,
#
#        [[137, 132, 129],
#         [137, 132, 129],
#         [137, 132, 129],
#         ...,
#         [150, 143, 140],
#         [151, 144, 141],
#         [154, 147, 144]],
#
#        [[136, 131, 128],
#         [136, 131, 128],
#         [136, 131, 128],
#         ...,
#         [152, 145, 142],
#         [152, 145, 142],
#         [154, 147, 144]],
#
#        [[135, 130, 127],
#         [135, 130, 127],
#         [135, 130, 127],
# ...

# %%
plt.imshow(image)
